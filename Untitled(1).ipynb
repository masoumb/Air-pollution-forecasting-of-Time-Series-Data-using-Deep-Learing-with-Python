# %% [markdown]
# # 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %%
# Read data

# %%
df = pd.read_csv('bank.xls')

# %%
# Head of data
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# # 2. Data cleaning and Analysis

# %% [markdown]
# # Statistitics of columns:

# %%
df.describe()
# This shows the statistics of numerical columns.
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %% [markdown]
# 1. Age of customers is between 18 & 95
# 2. Balance : between -6847 & 81204$
# 3. day : last contact day of the month is between 1 & 31
# 4. duration : last contact duration is between 2 & 3881
# 5. campaign : number of contacts performed during this campaign for different customers is between 1 & 63
# 6. pdays : number of days that passed by after the client was last contacted from a previous campaign is between -1 & 854
# 7. previous : number of contacts performed before this campaign and for this client is between 0 & 58

# %% [markdown]
# # Target/Output:
# - This dataset explores to see the result for marketting and its effect on the deposite of customers, wheather or not they will deposite. The column deposite is the target that we can predict using relevant machine learning technique.

# %% [markdown]
# # Information about dataset

# %%
df.info()
# All the clumns are non-null.
# We have a dataset of 11162 rows with 17 features
# The type of columns are determined below.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df.isnull().sum() 
# No null values
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# # Categorical attributes value_count

# %%
print(df.job.value_counts(),sep = '\n')
print("*"*35)
print(df.marital.value_counts(),sep = '\n')
print("*"*35)
print(df.education.value_counts(),sep = '\n')
print("*"*35)
print(df.default.value_counts(),sep = '\n')
print("*"*35)
print(df.housing.value_counts(),sep = '\n')
print("*"*35)
print(df.loan.value_counts(),sep = '\n')
print("*"*35)
print(df.contact.value_counts(),sep = '\n')
print("*"*35)
print(df.month.value_counts(),sep = '\n')
print("*"*35)
print("Previous campaign outcome:",df.poutcome.value_counts(),sep = '\n')
print("*"*35)
print("Outcome of the current campaign/customer's subscription to bank deposit:",df.deposit.value_counts(),sep = '\n')
print("*"*35)
# Out:
# job
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: count, dtype: int64
# ***********************************
# marital
# married     6351
# single      3518
# divorced    1293
# Name: count, dtype: int64
# ***********************************
# education
# secondary    5476
# tertiary     3689
# primary      1500
# unknown       497
# Name: count, dtype: int64
# ***********************************
# default
# no     10994
# yes      168
# Name: count, dtype: int64
# ***********************************
# housing
# no     5881
# yes    5281
# Name: count, dtype: int64
# ***********************************
# loan
# no     9702
# yes    1460
# Name: count, dtype: int64
# ***********************************
# contact
# cellular     8042
# ...

# %% [markdown]
# # Number of uniques

# %%
df.nunique()
# Out:
# age            76
# job            12
# marital         3
# education       4
# default         2
# balance      3805
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1428
# campaign       36
# pdays         472
# previous       34
# poutcome        4
# deposit         2
# dtype: int64

# %% [markdown]
# # Insights:
#
# 1. both categorical and non-categorical data exist in the dataset.
# 2. There are unknown columns as well.

# %% [markdown]
# # Duplicates

# %%
df.duplicated().sum()
df.duplicated().value_counts() # There are no duplicates to be removes
# Out:
# False    11162
# Name: count, dtype: int64

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# # Some data cleaning

# %%
df.job.unique()
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
# Let's remove "." from job title "admin."
df['job'].replace('admin.', 'Admin', inplace=True)

# %%
df.job.unique()
# Out:
# array(['Admin', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# ## Deposite

# %%
df['deposit'].value_counts()/df.shape[0]
# Out:
# deposit
# no     0.52616
# yes    0.47384
# Name: count, dtype: float64

# %%
plt.figure(figsize=(4,3))
sns.countplot(data = df, x = 'deposit')
plt.xlabel('')
plt.title('Subscribe to a Term Deposit?')
plt.tight_layout();
plt.show()

# %% [markdown]
# ## Insights from deposite
# - Data looks almost balanced and is shown in the figure below:

# %% [markdown]
# ## Customer Information

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Client Deposit Information')

fig1 = sns.countplot(ax=axes[0,0], data=df, x='job')
fig1.set_xticklabels(fig1.get_xticklabels(), rotation=45, horizontalalignment='right')

fig2 = sns.countplot(ax=axes[0,1], data=df, x='housing')
fig2.set_xticklabels(fig2.get_xticklabels(), rotation=45, horizontalalignment='right')

fig3 = sns.countplot(ax=axes[0,2], data=df, x='education')
fig3.set_xticklabels(fig3.get_xticklabels(), rotation=45, horizontalalignment='right')

fig4 = sns.countplot(ax=axes[1,0], data=df, x='default')
fig4.set_xticklabels(fig4.get_xticklabels(), rotation=45, horizontalalignment='right')

fig5 = sns.countplot(ax=axes[1,1], data=df, x='loan')
fig5.set_xticklabels(fig5.get_xticklabels(), rotation=45, horizontalalignment='right')

fig6 = sns.countplot(ax=axes[1,2], data=df, x='contact')
fig6.set_xticklabels(fig6.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.subplots_adjust(hspace = 0.5)
# sns.set(font_scale=2.5)

# %% [markdown]
# ## Insights from Customer Information
# - Among jobs, most frequent job titles are  bank clients are "managemnent", "blue_collar", "technician", "admin", respectively.
# - Most Job titles of " housemaid", "enterpreneur", "unemployed"/"self_employed" & "student" have the less frequency among bank clients.
# - Number of clients with no housing are a bit higher than those with housing.
# - Most customers have secendory education.
# - Most customers have not defaulted their loans previously.
# - Most customers have no loan.
# - Most customers were contacted using "cellular" method.

# %% [markdown]
# ## Categorical Feature Analysis

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Client Deposit Information')

fig1 = sns.countplot(ax=axes[0,0], data=df, x='job',  hue='deposit')
fig1.set_xticklabels(fig1.get_xticklabels(), rotation=45, horizontalalignment='right')

fig2 = sns.countplot(ax=axes[0,1], data=df, x='housing', hue='deposit')
fig2.set_xticklabels(fig2.get_xticklabels(), rotation=45, horizontalalignment='right')

fig3 = sns.countplot(ax=axes[0,2], data=df, x='education', hue='deposit')
fig3.set_xticklabels(fig3.get_xticklabels(), rotation=45, horizontalalignment='right')

fig4 = sns.countplot(ax=axes[1,0], data=df, x='default', hue='deposit')
fig4.set_xticklabels(fig4.get_xticklabels(), rotation=45, horizontalalignment='right')

fig5 = sns.countplot(ax=axes[1,1], data=df, x='loan', hue='deposit')
fig5.set_xticklabels(fig5.get_xticklabels(), rotation=45, horizontalalignment='right')

fig6 = sns.countplot(ax=axes[1,2], data=df, x='marital', hue='deposit')
fig6.set_xticklabels(fig6.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.subplots_adjust(hspace = 0.5)
# sns.set(font_scale=2.5)

# %% [markdown]
# ## Insights from Some Categorical Features:
# 1.  Job
# - Customers of management job title have shown the highest number of deposit and non-deposit.
# - Numnber of retired customers who have deosited are twice as those who have not deposited.
# - Customers with job title of Managment, retured, unemployed, and students are among the customers who have more deposites as compare with their non-deposit counterparts.
# - interstingly, number of customers holding the job title of "blue collar" who have deposited are almost hlaf of thoe wo have not deposited. Thus, in this category, number of non-deposits are higher than those who have deposited.
# 2. Housing
# - less number of customers with housing have deposited as compare with those who don'r own a house.
# 3. Education
# - Among all, thse with tertiary education are deposited more as compared with other secendary and primary education. It should be noted that number of customers with secondary education who have been contacted are higher that the rest.
# 4. Default
# - Most of the customers with no dafault have been contacted for campaign and among them, number of no to deposite is higher than  thse with yes to deposit.
# 5. Loan
# - Among those with no loan, number of yes and no to deposit are almost the same. And those with loan, numbr of no to deposit is higher. It might be due to the fact that some one with loan who has to return it won't be interested in depositing the money. So, we 'd better contact those with no loan.
# 6. Marital
# - Mostly married customers have been contacted. Less number of married customers have depoited as cmpared with those woh are single. It seems that more single customers prefer to deposite as compared to married couples.

# %% [markdown]
# ## Numerica Features

# %% [markdown]
# ## Age

# %%
plt.figure(figsize = (3,2))
sns.displot(data=df, x='age', hue='deposit', bins=30)
plt.title('Customer Age distribution over the Term "deposit"')
plt.show()

# %% [markdown]
# plt.figure(figsize = (4, 3))
# fig, axes = plt.subplots(1, 2)
# sns.histplot(df.loc[df['deposit']=='yes']['age'], bins=30, ax=axes[0])
# sns.histplot(df.loc[df['deposit']=='no']['age'], bins=30, ax=axes[1])
# plt.show()

# %% [markdown]
# ## Insights from Age
# - We see almost similar age distribution among customers who said yes to the rem deposit and no to the term deposit.

# %% [markdown]
# ## Numerical Data Correlation

# %%
df_corr = df.iloc[:, [0,5,9,11, 12, 13, 14, 16]]
df_corr['deposit'] = df_corr.deposit.map({'no':0, 'yes':1}).astype('uint8')
sns.heatmap(df_corr.corr(), annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ### Insights from heat-map Plot
# - Some feature show positive correlation:
# 1. "duration & deposite" features: The higher the duration of contact, the greater the chance of clients' subscription to the term deposit. Duration (of call in the last contact with customers) feature is the variable with the most correlation with target feature that is deposit.
# 2. "pdays&deposit" features: Pdays(number of days that passed by after the client was last contacted from a previous campaign) has a posite correlation with the ter deposit. This shows that i is better to give sutomers some time before starting with new campaing and contacts.
#
# 3. Previous (number of contacts before the current campaign) also has a positive correlation with the number of clients subscribed to the term deposit.
#
# 4. Campaign which is the number of contacts in the current campaign has a negative correlation with the term deposit. Increased number of contacts with customers doesn't seem to have a positive result in the subscription to the term deposit.

# %% [markdown]
# ## Campaign& Duration vs. Deposit

# %%
sns.scatterplot(x='campaign', y='duration', data=df, hue='deposit')
# Out:
# <Axes: xlabel='campaign', ylabel='duration'>

# %% [markdown]
# ## Insight from Campaign & Duration vs. Deposit
# - With increased duration call, there is higher chance that customers subscribe to the term deposit.
# - However, it is sobserved that with ncreasing the campaign, duration of calls has been deceased which might be the reason for having higher number of customers with choosing not to deposit.
# - Thefore, duration call is very impotant feature in this dataset as it is directly increasing the number of depsots of the customers. We can conclude that certaing number of contacts with appropriate duration call is required for a successful outcome which is yes to the term deposit.

# %% [markdown]
# ## poutcome vs. Deposit

# %%
sns.countplot(data=df, x='poutcome', hue='deposit')
# Out:
# <Axes: xlabel='poutcome', ylabel='count'>

# %% [markdown]
# ## Insights from poutcome vs. deposit
# - Most of the customers who have previously deposited, have decided to do so in this campaign as well.
# - Almost half of the previously failed campaigns, have deposited in the current campaign.
# - We have large amount of data with unknown previous campaign. Knowing the outcome might be very helpful in our analysis.

# %% [markdown]
# ## Month vs. Deposite

# %%
sns.countplot(df, x="month", hue='deposit')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %% [markdown]
# ### Insights from Month vs. Deposit:
# 1. Most number of clients were contacted in the months of May, June, July and August. The highest number of deposit is observed in the month of May.
# 2. During the months of January, Dec, March, October, and September very few customers are contacted.
# 3. The ratio of yes-depoits to no-deposits are higher among the clients contacted during April, September, February, December, March and October. So, it is recommended that more clients to be contacted during thses months as it might increase the subscription to the term deposte.

# %% [markdown]
# # Outliers
# - A data point that is distant from all other observations. It lies outside the overall distribution of dataset.

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(4, 2, figsize=(12, 10))
sns.boxplot(y='age', data=df, ax=axes[0][0])

sns.boxplot(y='balance', data=df, ax=axes[0][1])

sns.boxplot(y='day', data=df, ax=axes[1][0])

sns.boxplot(y='duration', data=df, ax=axes[1][1])

sns.boxplot(y='campaign', data=df, ax=axes[2][0])

sns.boxplot(y='pdays', data=df, ax=axes[2][1])

sns.boxplot(y='previous', data=df, ax=axes[3][0])
# Out:
# <Axes: ylabel='previous'>

# %% [markdown]
# # Train/Test Split

# %% [markdown]
# - Due to the lack of time, I will be using only numerical data for prediction using Logistic regression.

# %%
# Let's map the yes to 1 and no to 0 in df['deposit']
df['deposit'] = df['deposit'].map({'yes': 1, 'no': 0})
y = df['deposit']

# %%
# Only grab numerical columns
x = df.iloc[:, [0,5,9,11, 12, 13, 14]]

# %%
x
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 0       59     2343    5      1042         1     -1         0
# 1       56       45    5      1467         1     -1         0
# 2       41     1270    5      1389         1     -1         0
# 3       55     2476    5       579         1     -1         0
# 4       54      184    5       673         2     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 11157   33        1   20       257         1     -1         0
# 11158   39      733   16        83         4     -1         0
# 11159   32       29   19       156         2     -1         0
# 11160   43        0    8         9         2    172         5
# 11161   34        0    9       628         1     -1         0
#
# [11162 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((8929, 7), (2233, 7), (8929,), (2233,))

# %%
x_train
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 3955    28     5741   10      1042         5    200         3
# 11150   34      355   21       314         3     -1         0
# 5173    48      201   10       594         1     91         1
# 3017    53     1961   15       351         1     -1         0
# 2910    53     1624   11       166         3     97         7
# ...    ...      ...  ...       ...       ...    ...       ...
# 5734    47      761   11        80         2     -1         0
# 5191    28      159   16       449         2     33         4
# 5390    35     1144   20       197        13     -1         0
# 860     51      746   25       372         5     -1         0
# 7270    30        2   23       269         1     -1         0
#
# [8929 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression()
logistic_model.fit(x_train,y_train)
y_pred = logistic_model.predict(x_test)
print(classification_report(y_test, y_pred, target_names=['Yes', 'No']))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.72      0.76      0.74      1166
#           No       0.72      0.68      0.70      1067
#
#     accuracy                           0.72      2233
#    macro avg       0.72      0.72      0.72      2233
# weighted avg       0.72      0.72      0.72      2233

# %%
# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7223466188983431

# %%
model = XGBClassifier(tree_method = 'exact')
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
cm_undersampling = confusion_matrix(y_test, y_pred)
print(accuracy_score(y_test,y_pred))
print(cm_undersampling)
print(classification_report(y_test,y_pred))
# Out:
# 0.7962382445141066
# [[926 240]
#  [215 852]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80      1166
#            1       0.78      0.80      0.79      1067
#
#     accuracy                           0.80      2233
#    macro avg       0.80      0.80      0.80      2233
# weighted avg       0.80      0.80      0.80      2233

# %% [markdown]
# - As it can be seen, the accuracy is not much. That is due to the droping of many categorical features.
# - We should consider the categorical features.
# - We get 80% accuracy with better model selection.
# - So, the model is also playing an important role in prediction results.
